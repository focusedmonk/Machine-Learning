# %%
import requests
import pandas as pd

# %%
pd.set_option('display.max_columns', None)

# %%
city_id = ['134', '5', '4709', '2', '2378', '2423', '3686', '5732', '777', '1692', '6', '132', '6105', '290']
cars_list = []
for city in city_id:
    for page in range(1, 125):
        r = requests.get('https://api-sell24.cars24.team/buy-used-car?sort=P&serveWarrantyCount=true&gaId=331146332.1622358282' + 
                         '&listingCohortABTest=CONTROL&page='+str(page)+'&storeCityId=' + city)
        json = r.json()
        cars_list.extend(json['data']['content'])

# %%
len(cars_list)
# Out:
# 7400

# %%
tv_cars = pd.DataFrame(cars_list)

# %%
tv_cars.columns
# Out:
# Index(['carId', 'carName', 'year', 'fuelType', 'kilometerDriven', 'price',
#        'mainImage', 'inspectionMainImage', 'baseUrl', 'dispositionStatus',
#        'media', 'city', 'views', 'bodyType', 'transmission', 'storeName',
#        'variant', 'isC24Assured', 'registrationCity', 'registrationState',
#        'isTopSelling', 'calculatedScore', 'registrationNumber', 'carSource',
#        'make', 'model', 'lmsShareLink', 'inventoryStatus', 'ownerNumber',
#        'parkingYardId', 'c24Quote', 'originalPrice', 'dealRating',
#        'sellerBuddyId', 'createdDate', 'offerCount', 'threeSixtyViewUrl',
#        'spinCarImageSync', 'spinCarMedia', 'isCFEnabled', 'inventoryState',
#        'storeCityId', 'isFavouriteLms', 'ownerName', 'emiStartingValue',
#        'cashDownPayment', 'carScores', 'ciVehicleLocationInfo',
#        'ciChargesApplicable', 'reserved', 'cars24Owned', 'warrantyAvailable'],
#       dtype='object')

# %%
tv_cars = tv_cars[tv_cars.city != 'Coimbatore']

# %%
tv_cars.to_csv('backup.csv', index=False)

# %%
cols = ['mainImage', 'inspectionMainImage', 'carScores', 'baseUrl', 'calculatedScore', 'storeName', 'ownerName',
       'dispositionStatus', 'media', 'lmsShareLink', 'parkingYardId', 'sellerBuddyId',
       'offerCount', 'threeSixtyViewUrl', 'spinCarImageSync', 'spinCarMedia', 'inventoryState',
       'storeCityId', 'isFavouriteLms', 'carScores', 'ciVehicleLocationInfo', 
       'ciChargesApplicable', 'cars24Owned']
tv_cars.drop(cols, axis=1, inplace=True)
print(len(cols))
tv_cars.head()
# Out:
# 23
#         carId            carName  year fuelType  kilometerDriven   price  \
# 0  1009580428       Maruti Swift  2015   Petrol             8063  386399
# 1  1005820423    Maruti Alto 800  2014   Petrol             5383  285699
# 2  1124764129        Maruti Ritz  2011   Petrol            17980  270699
# 3  1052990821    Maruti Alto 800  2016   Petrol            23104  265499
# 4  1004180023  Hyundai Grand i10  2017   Petrol            23402  477699
#
#     city  views   bodyType transmission          variant  isC24Assured  \
# 0  Noida  18715  Hatchback       Manual          LXI OPT          True
# 1  Noida   8359  Hatchback       Manual              VXI          True
# 2  Noida   1841  Hatchback       Manual        VXI BS IV          True
# 3  Noida   2676  Hatchback       Manual              LXI          True
# 4  Noida    609  Hatchback       Manual  SPORTS 1.2 VTVT          True
#
#   registrationCity registrationState  isTopSelling registrationNumber  \
# ...

# %%
tv_cars.shape
# Out:
# (7399, 30)

# %%
tv_cars.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 7399 entries, 0 to 7399
# Data columns (total 30 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   carId               7399 non-null   object
#  1   carName             7399 non-null   object
#  2   year                7399 non-null   int64
#  3   fuelType            7399 non-null   object
#  4   kilometerDriven     7399 non-null   int64
#  5   price               7399 non-null   int64
#  6   city                7399 non-null   object
#  7   views               7399 non-null   int64
#  8   bodyType            7296 non-null   object
#  9   transmission        6843 non-null   object
#  10  variant             7399 non-null   object
#  11  isC24Assured        7399 non-null   bool
#  12  registrationCity    7389 non-null   object
#  13  registrationState   7389 non-null   object
#  14  isTopSelling        7399 non-null   bool
# ...

# %%
tv_cars.rename(columns={
    'carId': 'id',
    'carName': 'car_name',
    'year': 'yr_mfr',
    'fuelType': 'fuel_type',
    'kilometerDriven': 'kms_run',
    'price': 'sale_price',
    'views': 'times_viewed',
    'bodyType': 'body_type',
    'isC24Assured': 'assured_buy',
    'registrationCity': 'registered_city',
    'registrationState': 'registered_state',
    'isTopSelling': 'is_hot',
    'registrationNumber': 'rto',
    'carSource': 'source',
    'inventoryStatus': 'car_availability',
    'ownerNumber': 'total_owners',
    'c24Quote': 'broker_quote',
    'originalPrice': 'original_price',
    'dealRating': 'car_rating',
    'createdDate': 'ad_created_on',
    'isCFEnabled': 'fitness_certificate',
    'emiStartingValue': 'emi_starts_from',
    'cashDownPayment': 'booking_down_pymnt',
    'warrantyAvailable': 'warranty_avail'
}, inplace=True)

# %%
tv_cars.head()
# Out:
#            id           car_name  yr_mfr fuel_type  kms_run  sale_price  \
# 0  1009580428       Maruti Swift    2015    Petrol     8063      386399
# 1  1005820423    Maruti Alto 800    2014    Petrol     5383      285699
# 2  1124764129        Maruti Ritz    2011    Petrol    17980      270699
# 3  1052990821    Maruti Alto 800    2016    Petrol    23104      265499
# 4  1004180023  Hyundai Grand i10    2017    Petrol    23402      477699
#
#     city  times_viewed  body_type transmission          variant  assured_buy  \
# 0  Noida         18715  Hatchback       Manual          LXI OPT         True
# 1  Noida          8359  Hatchback       Manual              VXI         True
# 2  Noida          1841  Hatchback       Manual        VXI BS IV         True
# 3  Noida          2676  Hatchback       Manual              LXI         True
# 4  Noida           609  Hatchback       Manual  SPORTS 1.2 VTVT         True
#
# ...

# %%
unq_counts = []
for col in tv_cars:
    unq_counts.append(tv_cars[col].nunique())
df = pd.DataFrame(columns=['Name', 'Unique Values'])
df['Name'] = tv_cars.columns
df['Unique Values'] = unq_counts
df
# Out:
#                    Name  Unique Values
# 0                    id           7399
# 1              car_name            185
# 2                yr_mfr             24
# 3             fuel_type              5
# 4               kms_run           7176
# 5            sale_price           4519
# 6                  city             13
# 7          times_viewed           3151
# 8             body_type              5
# 9          transmission              2
# 10              variant            949
# 11          assured_buy              2
# 12      registered_city            243
# 13     registered_state             16
# 14               is_hot              2
# 15                  rto            263
# 16               source              6
# 17                 make             34
# 18                model            192
# 19     car_availability              6
# 20         total_owners              6
# 21         broker_quote           6536
# 22       original_price           3987
# ...

# %%
tv_cars.fitness_certificate.value_counts()
# Out:
# True     7246
# False     145
# Name: fitness_certificate, dtype: int64

# %%
tv_cars.fuel_type = tv_cars.fuel_type.map({'Petrol': 'petrol', 'Diesel': 'diesel', 'Petrol + CNG': 'petrol & CNG', 'Petrol + LPG': 'petrol & LPG', 
                      'Electric': 'electric'})

tv_cars.source = tv_cars.source.map({'GS_CAR': 'inperson_sale', 'GS_DEALER': 'inperson_sale', 'CUSTOMER_CARE': 'online', 'MANUAL_UPLOAD': 'online',
                    'C2C_DEALER_CAR': 'customer_to_customer', 'CLASSIFIED_CAR': 'inperson_sale'
                   })

tv_cars.car_availability = tv_cars.car_availability.map({'STOCK_IN': 'in_stock', 'IN_TRANSIT': 'in_transit', 'NEW_CAR': 'in_stock', 'BID_WON': 'in_stock',
                             'PICKUP_REQUEST': 'pickup_pending', 'STOCK_OUT': 'out_of_stock'})
tv_cars.registered_city.unique()
# Out:
# array(['Delhi', 'Ghaziabad', 'Noida', 'Agra', 'New Delhi', 'Gurgaon',
#        'Panchkula', 'Meerut', 'Faridabad', 'Goutam  Budd  Nagar',
#        'Bareilly', 'Bulandshahr', 'Jhajjar', 'Auraiya', 'Raebarely',
#        'Sonipat', 'Navi Mumbai', 'Mathura', 'Bulandshahar', 'Hathras',
#        'Kanpur', 'Lucknow', None, 'Badaun', 'Yamunanagar', 'Palwal',
#        'Sohana', 'Bhiwani', 'Karnal', 'Rewari', 'Ambala', 'Rohtak',
#        'Mahendragarh', 'Aligarh', 'Chandigarh', 'Gorakhpur',
#        'Bahadurgarh', 'Bawal', 'SONEPAT', 'Jhalawar', 'Delhi West',
#        'MUMBAI WEST', 'Charkhi Dadri', 'MUMBAI EAST', 'Pali', 'Hisar',
#        'BANGLORE-CAFE DLY', 'Bengaluru', 'Electronic City',
#        'BANGALORE K R PURAM', 'BANGALORE SOUTH', 'BANGALORE CENTRAL',
#        'Mysore', 'Chikamagalur', 'Chickballapur', 'Kolar', 'Devanahalli',
#        'Gulbarga', 'Tumkur', 'Belgaum', 'Ullal', 'Dharward', 'Dharwad',
#        'Mangalore', 'Karwar', 'Sagar', 'Madikeri', 'Udupi', 'Bidadi',
# ...

# %%
tv_cars.variant = tv_cars.variant.str.lower()
tv_cars.fuel_type = tv_cars.fuel_type.str.lower()
tv_cars.car_name = tv_cars.car_name.str.lower()
tv_cars.city = tv_cars.city.str.lower()
tv_cars.body_type = tv_cars.body_type.str.lower()
tv_cars.registered_city = tv_cars.registered_city.str.lower()
tv_cars.registered_state = tv_cars.registered_state.str.lower()
tv_cars.rto = tv_cars.rto.str.lower()
tv_cars.make = tv_cars.make.str.lower()
tv_cars.model = tv_cars.model.str.lower()
tv_cars.car_rating = tv_cars.car_rating.str.lower()
tv_cars.transmission = tv_cars.transmission.str.lower()

# %%
tv_cars.head()
# Out:
#            id           car_name  yr_mfr fuel_type  kms_run  sale_price  \
# 0  1009580428       maruti swift    2015    petrol     8063      386399
# 1  1005820423    maruti alto 800    2014    petrol     5383      285699
# 2  1124764129        maruti ritz    2011    petrol    17980      270699
# 3  1052990821    maruti alto 800    2016    petrol    23104      265499
# 4  1004180023  hyundai grand i10    2017    petrol    23402      477699
#
#     city  times_viewed  body_type transmission          variant  assured_buy  \
# 0  noida         18715  hatchback       manual          lxi opt         True
# 1  noida          8359  hatchback       manual              vxi         True
# 2  noida          1841  hatchback       manual        vxi bs iv         True
# 3  noida          2676  hatchback       manual              lxi         True
# 4  noida           609  hatchback       manual  sports 1.2 vtvt         True
#
# ...

# %%
tv_cars.shape
# Out:
# (7399, 30)

# %%
test = tv_cars.sample(1000)
tv_cars.drop(index=test.index, inplace=True)

# %%
tv_cars.shape
# Out:
# (6399, 30)

# %%
test.shape
# Out:
# (1000, 30)

# %%
tv_cars.id = list(range(1, len(tv_cars)+1))
test.id = list(range(1, len(test)+1))

# %%
tv_cars.id.describe()
# Out:
# count    6399.000000
# mean     3200.000000
# std      1847.376518
# min         1.000000
# 25%      1600.500000
# 50%      3200.000000
# 75%      4799.500000
# max      6399.000000
# Name: id, dtype: float64

# %%
test.id.describe()
# Out:
# count    1000.000000
# mean      500.500000
# std       288.819436
# min         1.000000
# 25%       250.750000
# 50%       500.500000
# 75%       750.250000
# max      1000.000000
# Name: id, dtype: float64

# %%
tv_cars.to_csv('train.csv', index=False)
test.to_csv('test.csv', index=False)
